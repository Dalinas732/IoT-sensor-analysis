# %%
"""
Measured occupancy might miscount or reset, especially if sensors drift.

Flow-based occupancy may miss people entering/exiting elsewhere or accumulate small errors.

The two sources are in close agreement (differences only single digits even at hundreds of occupants), which shows the sensors are generally reliable.

To balance their strengths and mitigate weaknesses, I use the average of the two.

Finally, I round up to the nearest integer so the metric always reflects a physically possible headcount (no “half people,” and no risk of undercounting near zero).
"""

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read parquet
df_occ = pd.read_parquet("data/occupancy.parquet")

# %%
# This is how we will take in account the in and out sensors at the entry point, which is another form of accurate occupation data 
def running_occ(flow):
    occ = []
    total = 0
    for f in flow:
        total += f
        if total < 0:
            total = 0
        occ.append(total)
    return occ

# %%
# Here are the important distingusing features when comparing values. Prevents mixing buildings and such
group_cols = ["organization_id","state","city", "building_name", "space_name", "date_daily"]

# %%
# Creates an occupancy estimate based on flow (in - out)
# Calculates an average between the two. Rounds up to nearest int to favor not missing people.
df = df_occ.copy()
df["flow"] = df["people_in"].fillna(0) - df["people_out"].fillna(0)
df["flow_occ"] = df.groupby(group_cols)["flow"].transform(running_occ)
df["avg_occ"] = np.ceil((df["flow_occ"] + df["occupancy"]) / 2).astype(int)

# %%
# Writes to parquet with new metric for data
df.to_parquet("occupancy_new_metric.parquet")

# %%
df
# Out:
#                 organization_id             state       city building_name  \
# 0      63f4d9f01ae6380cd40791EY           Ontario    Toronto    Building_1
# 1      63f4d9f01ae6380cd40791EY           Ontario    Toronto   Building_10
# 2      63f4d9f01ae6380cd40791EY           Alberta   Edmonton   Building_11
# 3      63f4d9f01ae6380cd40791EY  British Columbia  Vancouver   Building_12
# 4      63f4d9f01ae6380cd40791EY           Ontario    Toronto   Building_13
# ...                         ...               ...        ...           ...
# 10228  63f4d9f01ae6380cd40791EY          Michigan    Detroit   Building_41
# 10229  63f4d9f01ae6380cd40791EY           Alberta   Edmonton    Building_5
# 10230  63f4d9f01ae6380cd40791EY           Alberta   Edmonton    Building_5
# 10231  63f4d9f01ae6380cd40791EY  British Columbia  Vancouver    Building_6
# 10232  63f4d9f01ae6380cd40791EY  British Columbia  Vancouver    Building_6
#
#                space_name space_type space_description  capacity  \
# 0       Space1_Building_1   Building     Main Entrance       800
# 1      Space1_Building_10      Tower     Main Entrance       475
# 2      Space1_Building_11      Tower     Main Entrance       590
# 3      Space1_Building_12      Tower     Main Entrance       580
# 4      Space1_Building_13      Tower     Main Entrance       900
# ...                   ...        ...               ...       ...
# 10228  Space1_Building_41   Building     Main Entrance       435
# 10229   Space2_Building_5      Tower     Main Entrance      1218
# 10230   Space1_Building_5   Building     Main Entrance      1218
# 10231   Space1_Building_6   Building     Main Entrance      1322
# 10232   Space2_Building_6      Tower     Main Entrance      1322
#
#                 date_time date_daily  people_in  people_out  traffic  \
# 0     2023-03-05 00:00:00 2023-03-05        0.0         0.0      0.0
# 1     2023-03-05 00:00:00 2023-03-05        0.0         2.0      2.0
# 2     2023-03-05 00:00:00 2023-03-05        7.0         8.0     15.0
# 3     2023-03-05 00:00:00 2023-03-05        3.0         2.0      5.0
# 4     2023-03-05 00:00:00 2023-03-05        0.0         0.0      0.0
# ...                   ...        ...        ...         ...      ...
# 10228 2023-03-11 19:00:00 2023-03-11        0.0         0.0      0.0
# 10229 2023-03-11 19:00:00 2023-03-11        0.0         0.0      0.0
# 10230 2023-03-11 19:00:00 2023-03-11        0.0         3.0      3.0
# 10231 2023-03-11 19:00:00 2023-03-11        3.0         7.0     10.0
# 10232 2023-03-11 19:00:00 2023-03-11        4.0         1.0      5.0
#
#        occupancy  flow  flow_occ  avg_occ
# 0            0.0   0.0       0.0        0
# 1            2.0  -2.0       0.0        1
# 2            2.0  -1.0       0.0        1
# 3            5.0   1.0       1.0        3
# 4            2.0   0.0       0.0        1
# ...          ...   ...       ...      ...
# 10228        1.0   0.0       1.0        1
# 10229        1.0   0.0       0.0        1
# 10230        0.0  -3.0       0.0        0
# 10231        3.0  -4.0       0.0        2
# 10232        8.0   3.0       9.0        9
#
# [10233 rows x 17 columns]
